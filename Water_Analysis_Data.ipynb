# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("water_potability.csv")
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
col = pd.DataFrame(df.columns)
col
# Out:
#                  0
# 0               ph
# 1         Hardness
# 2           Solids
# 3      Chloramines
# 4          Sulfate
# 5     Conductivity
# 6   Organic_carbon
# 7  Trihalomethanes
# 8        Turbidity
# 9       Potability

# %%
print("Train Data Information:\n", df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               3276 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          3276 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3276 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB
# Train Data Information:
#  None

# %%
print("Train Data Information:\n", df.describe())
# Out:
# Train Data Information:
#                  ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.608364
# std       1.469956    32.879761   8768.570828     1.583085    36.143851
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.277673   176.850538  15666.690297     6.127421   317.094638
# 50%       7.080795   196.967627  20927.833607     7.130299   333.073546
# 75%       7.870050   216.667456  27332.762127     8.114887   350.385756
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# ...

# %%
df.dtypes
# Out:
# ph                 float64
# Hardness           float64
# Solids             float64
# Chloramines        float64
# Sulfate            float64
# Conductivity       float64
# Organic_carbon     float64
# Trihalomethanes    float64
# Turbidity          float64
# Potability           int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# ph                 14.987790
# Hardness            0.000000
# Solids              0.000000
# Chloramines         0.000000
# Sulfate            23.840049
# Conductivity        0.000000
# Organic_carbon      0.000000
# Trihalomethanes     4.945055
# Turbidity           0.000000
# Potability          0.000000
# dtype: float64

# %%
df.shape
# Out:
# (3276, 10)

# %%
df["ph"].fillna(df["ph"].mean(),inplace=True)
# Out:
# C:\Users\sivam\AppData\Local\Temp\ipykernel_12136\1480077206.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ph"].fillna(df["ph"].mean(),inplace=True)

# %%
df["Sulfate"].fillna(df["Sulfate"].median(),inplace=True)
# Out:
# C:\Users\sivam\AppData\Local\Temp\ipykernel_12136\1643071592.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Sulfate"].fillna(df["Sulfate"].median(),inplace=True)

# %%
df["Trihalomethanes"].fillna(df["Trihalomethanes"].mean(),inplace=True)
# Out:
# C:\Users\sivam\AppData\Local\Temp\ipykernel_12136\2177296937.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Trihalomethanes"].fillna(df["Trihalomethanes"].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
# Distribution of numerical features in train data
df.hist(figsize=(12, 10), bins=30)
plt.suptitle("Distribution of Numerical Features in Water Potability")
plt.show()

# %%
numeric_df=df.select_dtypes(include=["float","int"])

# %%
numeric_df.boxplot(figsize=(12, 6))
plt.xticks(rotation=45)
plt.title("Boxplot of Numerical Features in water potability")
plt.show()

# %%
corr_max=numeric_df.corr()

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.heatmap(corr_max, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap - Water Potability")
plt.show()

# %%
df.to_csv("water_potability.csv", index=False)

# %%
from sqlalchemy import create_engine
import pandas as pd

# Replace with your MySQL credentials
username = 'root'
password = 'MySQLsiva2003'
host = 'localhost:3306'
database = 'Water_Analysis_Data'

# Create the connection URL
connection_url = f'mysql+pymysql://{username}:{password}@{host}/{database}'

try:
    # Create an SQLAlchemy engine
    engine = create_engine(connection_url)
    print("Connected to the database successfully.")

    # Create a DataFrame to upload
    accounts_df = pd.read_csv('water_potability.csv')
    print("CSV file loaded successfully.")

    # Upload the DataFrame to MySQL
    accounts_df.to_sql('Water_Quality', con=engine, if_exists='replace', index=False)
    print("Data uploaded successfully.")

except Exception as e:
    print("An error occurred:", e)
# Out:
# Connected to the database successfully.
# CSV file loaded successfully.
# An error occurred: Could not reflect: requested table(s) not available in Engine(mysql+pymysql://root:***@localhost:3306/Water_Analysis_Data): (Water_Quality)
